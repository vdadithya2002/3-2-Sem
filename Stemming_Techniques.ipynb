# %% [markdown]
# <a href="https://colab.research.google.com/github/vdadithya2002/3-2-Sem/blob/Natural_Language_Processing/Stemming_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Porter Stemmer

# %%
import nltk
from nltk.stem import PorterStemmer

porter_stemmer = PorterStemmer()

words = ["running", "jumps", "happily", "programming"]

stemmed_words = [porter_stemmer.stem(word) for word in words]

print("Original Words:", words)
print("Stemmed Words:", stemmed_words)
# Out:
# Original Words: ['running', 'jumps', 'happily', 'programming']
# Stemmed Words: ['run', 'jump', 'happili', 'program']

# %% [markdown]
# ##Snowball Stemmer

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

def stemming_demo():

  stemmer = SnowballStemmer('english')

  test_words = [
      'running', 'runs', 'ran',
      'caring', 'cared', 'careful',
      'university', 'universities',
      'fairly', 'unfairly',
      'singing', 'singer', 'song'
  ]

  print("Basic Stemming Results:")
  print("-" * 30)

  for word in test_words:
    stem = stemmer.stem(word)
    print(f"{word:12} -> {stem}")
stemming_demo()
# Out:
# Basic Stemming Results:
# ------------------------------
# running      -> run
# runs         -> run
# ran          -> ran
# caring       -> care
# cared        -> care
# careful      -> care
# university   -> univers
# universities -> univers
# fairly       -> fair
# unfairly     -> unfair
# singing      -> sing
# singer       -> singer
# song         -> song

# %% [markdown]
# ##Lancaster Stemmer

# %%
import nltk

nltk.download('punkt_tab')

# !pip install stemming
from stemming.paicehusk import stem
from nltk.tokenize import word_tokenize

text = "The Cats are running swiftly"

words = word_tokenize(text)

stemmed_words = [stem(word) for word in words]

print("Original Words:", words)
print("Stemmed Words:", stemmed_words)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stemming: filename=stemming-1.0.1-py3-none-any.whl size=11123 sha256=0d4ad9dcf1e93b21b5c5e53d8a8c68f149847235715bb329668c3bd4157b6371
#   Stored in directory: /root/.cache/pip/wheels/20/d4/73/028ca44cd75949ad81250dd3ecea7e4c61b97672587b65ef35
# Successfully built stemming
# ...
# Original Words: ['The', 'Cats', 'are', 'running', 'swiftly']
# Stemmed Words: ['The', 'Cat', 'ar', 'run', 'swift']

# %% [markdown]
# ##Regexp Stemmer

# %% [markdown]
# ######The Regexp Stemmer is a flexible stemming algorithm provided by the NLTK library. It uses regular expressions (regex) to identify and remove specific prefixes or suffixes from words, making it highly customizable for domain-specific tasks. Unlike other stemmers, it allows users to define their own rules for stemming, making it suitable for specialized text processing needs.

# %%
from nltk.stem import RegexpStemmer

custom_rule = r'ing$|s$|e$|able$'

regexp_stemmer = RegexpStemmer(custom_rule, min=4)

words = ['cars', 'movies', 'bee', 'complete', 'advisable', 'running']

stemmed_words = [regexp_stemmer.stem(word) for word in words]

print("Original Words:", words)
print("Stemmed Words:", stemmed_words)
# Out:
# Original Words: ['cars', 'movies', 'bee', 'complete', 'advisable', 'running']
# Stemmed Words: ['car', 'movie', 'bee', 'complet', 'advis', 'runn']
